# %%
import pandas as pd
url = "https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv"
ds2 = pd.read_csv(url)
ds2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ds2['age_filled'] = ds2['Age'].fillna(ds2['Age'].median())
print('Заполнили пропуски медианой, пропусков остиалось:', ds2['age_filled'].isna().sum())
print((ds2['age_filled']).head(10))
# Out:
# Заполнили пропуски медианой, пропусков остиалось: 0
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5    28.0
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: age_filled, dtype: float64

# %%
results = {}
if 'Survived' in ds2.columns:
    results['survived_rate_overall'] = ds2['Survived'].mean()
    results['survived_by_sex'] = ds2.groupby('Sex')['Survived'].mean().to_dict()
    results['survived_by_pclass'] = ds2.groupby('Pclass')['Survived'].mean().to_dict()
    
results['median_age_by_pclass'] = ds2.groupby('Pclass')['age_filled'].median().to_dict()

print("Results (sample):")
for k,v in results.items():
    print(k,":", v)
res_df = pd.DataFrame({
    "metric:": list(results.keys()),
    "value:": [str(v) for v in results.values()]
})
out_name = "titanic_analysied.csv"
res_df.to_csv(out_name,index=False)
print("\nSaved report to", out_name)
# Out:
# Results (sample):
# survived_rate_overall : 0.3838383838383838
# survived_by_sex : {'female': 0.7420382165605095, 'male': 0.18890814558058924}
# survived_by_pclass : {1: 0.6296296296296297, 2: 0.47282608695652173, 3: 0.24236252545824846}
# median_age_by_pclass : {1: 35.0, 2: 28.0, 3: 28.0}
#
# Saved report to titanic_analysied.csv

# %% [markdown]
# Matplotlib

# %%
import  matplotlib.pyplot as plt

# %%
object = ["Python","C++","Java","PHP"]
perfomance = [10,7,8,4]
plt.bar(object, perfomance)
plt.title("Популяность языков")
plt.ylabel("Оценка")
plt.show()

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv"
tit = pd.read_csv(url)
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit['age_filled'] = tit['Age'].fillna(tit['Age'].median())
print('Заполнили пропуски медианой, пропусков остиалось:', tit['age_filled'].isna().sum())
print((tit['age_filled']).head(10))
# Out:
# Заполнили пропуски медианой, пропусков остиалось: 0
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5    28.0
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: age_filled, dtype: float64

# %%
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
results = {}

if 'Survived' in tit.columns:
  results['survived_rate_overall'] = tit['Survived'].mean()
  results['survived_by_sex'] = tit.groupby('Sex')['Survived'].mean().to_dict()
  results['survived_by_pclass'] = tit.groupby('Pclass')['Survived'].mean().to_dict()

results['median_age_by_pclass'] = tit.groupby('Pclass')['age_filled'].median().to_dict()

print("Results (sample):")
for k,v in results.items():
  print(k, ":", v)

res_df = pd.DataFrame({
    'metric:': list(results.keys()),
    'value:': [str(v) for v in results.values()]
})
out_name = 'titanic_analysied2.csv'
res_df.to_csv(out_name, index=False)
print("\nSaved report to", out_name)
# Out:
# Results (sample):
# survived_rate_overall : 0.3838383838383838
# survived_by_sex : {'female': 0.7420382165605095, 'male': 0.18890814558058924}
# survived_by_pclass : {1: 0.6296296296296297, 2: 0.47282608695652173, 3: 0.24236252545824846}
# median_age_by_pclass : {1: 35.0, 2: 28.0, 3: 28.0}
#
# Saved report to titanic_analysied2.csv

# %%
ds2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
